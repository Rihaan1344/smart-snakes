# %%
import pandas as pd
from get_path import get_path as gp

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_regression
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv(gp(bins=True))

# %%
df.head()
# Out:
#         mean radius      mean texture      mean perimeter          mean area  \
# 0   (11.207, 13.32]  (21.538, 24.495]   (87.203, 101.674]    (379.25, 615.0]
# 1  (19.658, 21.771]  (21.538, 24.495]  (116.145, 130.616]  (1086.5, 1322.25]
# 2   (11.207, 13.32]  (15.624, 18.581]    (72.732, 87.203]    (379.25, 615.0]
# 3   (9.094, 11.207]    (9.68, 12.667]    (58.261, 72.732]  (141.142, 379.25]
# 4   (13.32, 15.433]  (18.581, 21.538]   (87.203, 101.674]    (379.25, 615.0]
#
#    mean smoothness mean compactness       mean concavity mean concave points  \
# 0    (0.119, 0.13]   (0.182, 0.215]       (0.171, 0.213]     (0.0805, 0.101]
# 1  (0.0969, 0.108]  (0.0846, 0.117]       (0.128, 0.171]     (0.0805, 0.101]
# 2  (0.0969, 0.108]    (0.117, 0.15]     (0.0427, 0.0854]    (0.0201, 0.0402]
# 3  (0.0969, 0.108]  (0.052, 0.0846]  (-0.000427, 0.0427]    (0.0201, 0.0402]
# 4  (0.0969, 0.108]    (0.117, 0.15]      (0.0854, 0.128]    (0.0402, 0.0604]
#
#     mean symmetry mean fractal dimension  radius error
# 0  (0.217, 0.235]       (0.0737, 0.0784]        0.3063
# 1  (0.143, 0.161]       (0.0499, 0.0547]        0.7582
# 2   (0.18, 0.198]        (0.0642, 0.069]        0.1852
# 3   (0.18, 0.198]        (0.069, 0.0737]        0.2773
# 4   (0.161, 0.18]       (0.0595, 0.0642]        0.2130

# %%
x = df.iloc[:, :10]
y = df["radius error"]

# %%
x = OrdinalEncoder().fit_transform(x)

# %%
selector = SelectKBest(lambda x, y: mutual_info_regression(x, y, discrete_features = True), k = 5)

# %%
selector.fit_transform(x, y)
# Out:
# array([[0., 5., 2., 4., 4.],
#        [4., 1., 0., 3., 4.],
#        [0., 4., 2., 1., 1.],
#        [5., 3., 1., 0., 1.],
#        [1., 5., 2., 2., 2.],
#        [0., 5., 2., 2., 3.],
#        [0., 4., 2., 0., 0.],
#        [5., 3., 1., 1., 1.],
#        [0., 4., 2., 2., 3.],
#        [0., 5., 2., 4., 4.],
#        [1., 5., 3., 2., 4.],
#        [3., 1., 4., 2., 3.],
#        [0., 4., 2., 3., 3.],
#        [0., 4., 2., 0., 0.],
#        [5., 3., 1., 0., 0.],
#        [5., 3., 1., 0., 0.],
#        [1., 5., 3., 1., 2.],
#        [0., 4., 2., 0., 1.],
#        [2., 0., 4., 2., 4.],
#        [3., 1., 0., 1., 2.],
#        [0., 4., 2., 0., 1.],
#        [5., 3., 1., 0., 0.],
#        [3., 1., 0., 5., 5.],
#        [0., 4., 2., 1., 1.],
#        [0., 4., 2., 0., 0.],
#        [0., 4., 2., 0., 1.],
#        [2., 0., 3., 6., 6.],
#        [1., 5., 2., 0., 1.],
#        [1., 4., 2., 0., 0.],
#        [5., 3., 1., 0., 0.],
#        [1., 5., 2., 2., 2.],
#        [5., 3., 1., 1., 1.],
#        [5., 3., 1., 0., 0.],
#        [1., 0., 3., 6., 4.],
#        [3., 1., 4., 3., 4.],
#        [1., 4., 2., 0., 1.],
#        [3., 1., 4., 5., 4.],
#        [0., 4., 2., 3., 2.],
#        [0., 4., 2., 0., 0.],
#        [1., 5., 3., 0., 1.],
#        [1., 5., 2., 3., 4.],
#        [1., 5., 2., 0., 1.],
#        [4., 2., 0., 4., 6.],
#        [1., 5., 2., 1., 2.]])

# %%
import numpy as np
df.columns[np.append(selector.get_support(), False)]
# Out:
# Index(['mean radius', 'mean perimeter', 'mean area', 'mean concavity',
#        'mean concave points'],
#       dtype='str')
